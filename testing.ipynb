# %%
import pandas as pd

# %% [markdown]
# <h3>Create DataFrame

# %%
df= pd.read_csv('footballer_data.csv')
pd.set_option('display.max_columns', 75)
pd.set_option('display.max_rows', 100)

# %%
df.head()
# Out:
#              name  Age  Overall rating  Potential      ID  Height  Weight  \
# 0      J. Todibo    22              79         84  245388     190      88
# 1  B. Verbruggen    19              73         83  258498     194      89
# 2     M. Ugarte     21              79         85  253306     182      77
# 3      Z. Debast    18              70         84  254262     189      76
# 4     07 D. Last    37              61         60   21555     182      82
#
#     foot  Best overall Best position  Growth     Value   Wage  Release clause  \
# 0  Right            81            CB       5  24500000  37000        48400000
# 1  Right            73            GK      10   5500000   6000         9400000
# 2  Right            80           CDM       6  26000000  11000        57200000
# 3  Right            72           CDM      14   3500000   3000         7400000
# 4  Right            61            GK      -1         0      0               0
#
# ...

# %%
df_needed= df[["name","Age", "Dribbling / Reflexes", "Passing / Kicking", "Shooting / Handling",
    "International reputation", "Total mentality", "Shot power",
    "Total power", "Ball control", "Finishing","Value"]]

# %%
df_needed.sort_values(by='Value', ascending =False).head(10)
# Out:
#                name  Age  Dribbling / Reflexes  Passing / Kicking  \
# 61      K. Mbappé     23                    92                 80
# 30      E. Haaland    21                    80                 65
# 152     F. de Jong    25                    87                 86
# 12    Vinícius Jr.    21                    90                 74
# 120  K. De Bruyne     31                    86                 93
# 373     Rúben Dias    25                    68                 66
# 110   J. Kimmich      27                    84                 87
# 179        H. Kane    28                    83                 83
# 117          Pedri    19                    87                 81
# 302  G. Donnarumma    23                    89                 79
#
#      Shooting / Handling  International reputation  Total mentality  \
# 61                    89                         4              361
# 30                    92                         4              382
# ...
